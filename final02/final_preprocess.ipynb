# %%
import pandas as pd
df = pd.read_csv("tokyo_data.csv")
df["high"] = df[["high"]].astype("float")
df["low"] = df[["low"]].astype("float")
df
# Out:
#              date  high  low  max_precipitation_10min(mm)  \
# 0        1984/1/1  10.1  0.9                          0.0
# 1        1984/1/2   8.9  0.3                          0.0
# 2        1984/1/3   7.7  0.9                          1.0
# 3        1984/1/4  10.9  1.5                          0.5
# 4        1984/1/5   7.6  1.9                          0.0
# ...           ...   ...  ...                          ...
# 10222  2018/12/27  13.2  4.9                          0.0
# 10223  2018/12/28   8.4  1.8                          0.0
# 10224  2018/12/29   9.8 -0.7                          0.0
# 10225  2018/12/30  10.1  0.1                          0.0
# 10226  2018/12/31   8.9  0.8                          0.0
#
#        daylight_hours(hours)
# 0                        8.5
# 1                        7.0
# 2                        4.1
# 3                        6.5
# 4                        8.6
# ...                      ...
# 10222                    8.0
# ...

# %%
df[:365]
# Out:
#            date  high  low  max_precipitation_10min(mm)  daylight_hours(hours)
# 0      1984/1/1  10.1  0.9                          0.0                    8.5
# 1      1984/1/2   8.9  0.3                          0.0                    7.0
# 2      1984/1/3   7.7  0.9                          1.0                    4.1
# 3      1984/1/4  10.9  1.5                          0.5                    6.5
# 4      1984/1/5   7.6  1.9                          0.0                    8.6
# ..          ...   ...  ...                          ...                    ...
# 360  1984/12/26   6.4  0.3                          0.0                    6.3
# 361  1984/12/27   7.6 -0.7                          0.0                    5.1
# 362  1984/12/28   8.3 -0.1                          0.0                    6.8
# 363  1984/12/29   7.0  0.8                          0.0                    7.8
# 364  1984/12/30   8.0 -0.8                          0.0                    8.9
#
# [365 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(df.high[:365])
